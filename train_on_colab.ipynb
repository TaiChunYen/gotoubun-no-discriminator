# %%
# !git clone https://github.com/TaiChunYen/gotobun-no-discriminator.git
# Out:
# Cloning into 'gotobun-no-discriminator'...
# remote: Enumerating objects: 418, done.
# remote: Counting objects: 100% (418/418), done.
# remote: Compressing objects: 100% (406/406), done.
# remote: Total 418 (delta 22), reused 404 (delta 10), pack-reused 0
# Receiving objects: 100% (418/418), 22.13 MiB | 32.75 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd ./gotobun-no-discriminator
# Out:
# /content/gotobun-no-discriminator/gotobun-no-discriminator/gotobun-no-discriminator

# %%
# !python3.6 train.py
# Out:
# [epoch:1]
# 0 1.65330970287323
# Accuracy: 18 %
# 1 5.058833599090576
# Accuracy: 25 %
# 2 4.707366943359375
# Accuracy: 25 %
# 3 3.3623108863830566
# Accuracy: 25 %
# 4 4.074470520019531
# Accuracy: 6 %
# 5 2.571162462234497
# Accuracy: 25 %
# 6 3.3262572288513184
# Accuracy: 18 %
# 7 2.1269726753234863
# Accuracy: 31 %
# 8 2.8583450317382812
# Accuracy: 18 %
# 9 3.0782065391540527
# Accuracy: 25 %
# 10 1.603176474571228
# Accuracy: 25 %
# 11 1.5836151838302612
# Accuracy: 8 %
# Test Accuracy: 100 %
# Test Accuracy: 100 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# Test Accuracy: 0 %
# [epoch:2]
# 0 1.4030084609985352
# Accuracy: 18 %
# 1 2.0898752212524414
# Accuracy: 12 %
# 2 1.5837535858154297
# Accuracy: 18 %
# 3 3.036623001098633
# Accuracy: 18 %
# 4 2.1843531131744385
# Accuracy: 25 %
# 5 1.836588740348816
# Accuracy: 25 %
# 6 1.824360728263855
# ...
